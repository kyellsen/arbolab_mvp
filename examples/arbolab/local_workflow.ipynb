# %% [markdown]
# # ArboLab Local Workflow Example
#
# This notebook demonstrates how to use ArboLab locally in a pure Python environment.
# It covers:
# 1. Imports
# 2. Lab Initialization
# 3. Entity Management (CRUD)
# 4. Querying and Exploration

# %% [markdown]
# ## 1. Imports
#
# First, we import the central `Lab` entry point and the `LabRole` for permission management.

# %%
from pathlib import Path
from datetime import datetime
from sqlalchemy import select

from arbolab.lab import Lab
from arbolab.core.security import LabRole
from arbolab.models.core import Project, Experiment, Thing, Tree

# %% [markdown]
# ## 2. Lab Initialization
#
# We initialize a Lab by specifying a workspace root. If the directory doesn't exist, ArboLab will bootstrap it with a default configuration.

# %%
# Define where your lab should live
lab_path = Path("./examples_data/local_workflow").resolve()

# Open the Lab as an ADMIN
lab = Lab.open(workspace_root=lab_path, role=LabRole.ADMIN)

print(f"Lab initialized at: {lab.layout.root}")
print(f"Database path: {lab.layout.db_path}")
# Out:
# [2026-01-09 13:44:08] INFO     Creating new workspace directory at                                       ]8;id=341403;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/lab.py\lab.py]8;;\:]8;id=222269;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/lab.py#123\123]8;;\
#                                /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_dat
#                                a/local_workflow
# [2026-01-09 13:44:08] INFO     Created default config at                                              ]8;id=710589;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/config.py\config.py]8;;\:]8;id=908246;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/config.py#136\136]8;;\
#                                /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_
#                                data/local_workflow/config.yaml
# [2026-01-09 13:44:08] INFO     Creating database directory:                                            ]8;id=422806;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/layout.py\layout.py]8;;\:]8;id=176479;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/layout.py#47\47]8;;\
#                                /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_d
#                                ata/local_workflow/db
# [2026-01-09 13:44:08] INFO     Catalog version not found in DB. Sync needed.                  ]8;id=720304;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py\catalog_manager.py]8;;\:]8;id=322904;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py#45\45]8;;\
# [2026-01-09 13:44:08] INFO     Starting Catalog Sync (Target Version: 2026-01-08.01)...       ]8;id=215261;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py\catalog_manager.py]8;;\:]8;id=601448;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py#62\62]8;;\
# [2026-01-09 13:44:08] INFO     Created UnitOfMeasurement: UnitOfMeasurement #1                       ]8;id=216135;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=650212;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created UnitOfMeasurement: UnitOfMeasurement #2                       ]8;id=207221;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=646412;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created UnitOfMeasurement: UnitOfMeasurement #3                       ]8;id=726249;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=984727;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created ObservedProperty: Air Temperature                             ]8;id=680181;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=542721;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created ObservedProperty: Photosynthetic Photon Flux Density          ]8;id=705955;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=265821;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created ObservedProperty: Soil Moisture                               ]8;id=825525;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=331640;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created SensorModel: TMS-4                                            ]8;id=739880;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=159983;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created SensorModel: LI-190R                                          ]8;id=12707;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=969585;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created TreeSpecies: Fagus sylvatica                                  ]8;id=244329;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=840959;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created TreeSpecies: Picea abies                                      ]8;id=623817;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=985078;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Created TreeSpecies: Quercus robur                                    ]8;id=982871;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=936636;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Catalog Sync Completed.                                        ]8;id=915295;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py\catalog_manager.py]8;;\:]8;id=998696;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/core/catalog_manager.py#72\72]8;;\
# [2026-01-09 13:44:08] INFO     Created SysMetadata: <SysMetadata transient>                          ]8;id=944875;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=287935;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:08] INFO     Lab initialized at                                                         ]8;id=634161;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/lab.py\lab.py]8;;\:]8;id=81190;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/lab.py#79\79]8;;\
#                                /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_data
#                                /local_workflow (Role: LabRole.ADMIN)
# Lab initialized at: /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_data/local_workflow
# Database path: /mnt/data/kyellsen/410_Packages/arbolab_mvp/examples/arbolab/examples_data/local_workflow/db/arbolab.duckdb

# %% [markdown]
# ## 3. Creating and Managing Entities
#
# ArboLab uses a "Recipe-First" approach. Every modification is recorded, ensuring reproducibility.
# You can use `define_*`, `modify_*`, and `remove_*` methods directly on the `lab` object.

# %%
# 3.1 Create a Project
project = lab.define_project(
    name="Forest Monitoring 2026",
    description="Analyzing tree growth and health in the local test area."
)
print(f"Created Project: {project.name} (ID: {project.id})")

# 3.2 Create an Experiment within the project
experiment = lab.define_experiment(
    project_id=project.id,
    name="Spring Growth Campaign",
    start_time=datetime.now(),
    description="Initial measurements for the spring season."
)
print(f"Created Experiment: {experiment.name} (ID: {experiment.id})")

# 3.3 Create a 'Thing' (e.g., a Tree)
# First define the base 'Thing'
thing = lab.define_thing(
    project_id=project.id,
    name="Oak-01",
    kind="tree"
)

# Then add specific Tree metadata
tree = lab.define_tree(
    id=thing.id, # Must match the Thing ID
    height=1500, # in cm
    circumference=120
)
print(f"Created Tree with Thing ID: {thing.id}")
# Out:
# [2026-01-09 13:44:41] INFO     Created Project: Forest Monitoring 2026                               ]8;id=199886;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=526820;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# Created Project: Forest Monitoring 2026 (ID: 1)
# [2026-01-09 13:44:41] INFO     Created Experiment: Spring Growth Campaign                            ]8;id=108024;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=824349;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# Created Experiment: Spring Growth Campaign (ID: 1)
# [2026-01-09 13:44:41] INFO     Created Thing: Oak-01                                                 ]8;id=677472;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=993759;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# [2026-01-09 13:44:41] INFO     Created Tree: Tree #1                                                 ]8;id=563259;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py\database.py]8;;\:]8;id=832208;file:///mnt/data/kyellsen/410_Packages/arbolab_mvp/packages/arbolab/src/arbolab/database.py#87\87]8;;\
# Created Tree with Thing ID: 1

# %% [markdown]
# ### Modifying Entities
# Updating data is just as easy. Changes are also recorded in the workspace recipe.

# %%
# Update the project description
lab.modify_project(
    id=project.id, 
    description="Updated: Now including more sensors."
)

# Update tree height
lab.modify_tree(
    id=tree.id,
    height=1550
)
print("Entities updated successfully.")
# Out:
# Entities updated successfully.

# %% [markdown]
# ## 4. Querying Data
#
# You can access the internal database session for advanced querying using SQLAlchemy.

# %%
with lab.database.session() as session:
    # Query all projects
    stmt = select(Project)
    projects = session.execute(stmt).scalars().all()
    
    print(f"Found {len(projects)} projects in the Lab:")
    for p in projects:
        print(f" - {p.name} (ID: {p.id})")

    # Query trees with height > 1000
    stmt = select(Tree).where(Tree.height > 1000)
    big_trees = session.execute(stmt).scalars().all()
    print(f"\nTrees taller than 10m: {len(big_trees)}")
# Out:
# Found 1 projects in the Lab:
#  - Forest Monitoring 2026 (ID: 1)
#
# Trees taller than 10m: 1

# %% [markdown]
# ## 5. What else can ArboLab do?
#
# - **Recipes**: All your actions are stored in `current.json`. You can share this recipe to reproduce your exact workspace state elsewhere.
# - **Plugins**: Discover and use device plugins (like linescale or treeqinetic).
# - **Data Storage**: Local Parquet/DuckDB storage for high-performance time-series data.
